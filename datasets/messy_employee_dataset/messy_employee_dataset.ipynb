# %%
import pandas as pd
import importlib

import lib

importlib.reload(lib)

name = 'messy_employee_dataset'
log = lib.logger.getLogger(name)

# %%
filename = '/Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/messy_employee_dataset/messy_employee_dataset.csv'
df = lib.read_data(filename, sep=',')
# Out:
# Encoding: ascii
# Stripping whitespaces from messy_employee_dataset.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   object
#  1   First_Name         1020 non-null   object
#  2   Last_Name          1020 non-null   object
#  3   Age                809 non-null    float64
#  4   Department_Region  1020 non-null   object
#  5   Status             1020 non-null   object
#  6   Join_Date          1020 non-null   object
#  7   Salary             996 non-null    float64
#  8   Email              1020 non-null   object
#  9   Phone              1020 non-null   int64
#  10  Performance_Score  1020 non-null   object
#  11  Remote_Work        1020 non-null   bool
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 88.8+ KB

# %%
lib.info(df)
# Out:
# INFO
# -------------------------------------------------------------------------------
# Null INFO
# 2/12 columns contain null values
# 235 total null values
# -------------------------------------------------------------------------------
# Column "Employee_ID" has no null values
# Column "First_Name" has no null values
# Column "Last_Name" has no null values
# Column "Department_Region" has no null values
# Column "Status" has no null values
# Column "Join_Date" has no null values
# Column "Email" has no null values
# Column "Phone" has no null values
# Column "Performance_Score" has no null values
# Column "Remote_Work" has no null values
# Column "Age" has 211 null values
# Column "Salary" has 24 null values
#
# Risk Rate ---------------------------------------------------------------------
# Employee_ID          0.000000
# First_Name           0.000000
# Last_Name            0.000000
# Age                  0.206863
# Department_Region    0.000000
# Status               0.000000
# Join_Date            0.000000
# Salary               0.023529
# Email                0.000000
# Phone                0.000000
# Performance_Score    0.000000
# Remote_Work          0.000000
# dtype: float64
# Column Risk Rates
# Employee_ID          0.000000
# First_Name           0.000000
# Last_Name            0.000000
# Age                  0.206863
# Department_Region    0.000000
# Status               0.000000
# Join_Date            0.000000
# Salary               0.023529
# Email                0.000000
# Phone                0.000000
# Performance_Score    0.000000
# Remote_Work          0.000000
# dtype: float64
# -------------------------------------------------------------------------------
# Data Types Info
#                   has_different_types has_<NA>
# Employee_ID                     False        0
# First_Name                      False        0
# Last_Name                       False        0
# Age                             False      211
# Department_Region               False        0
# Status                          False        0
# Join_Date                       False        0
# Salary                          False       24
# Email                           False        0
# Phone                           False        0
# Performance_Score               False        0
# Remote_Work                     False        0
# -------------------------------------------------------------------------------
# /Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/lib/tools.py:576: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = result.fillna(0)
#                  Employee_ID  First_Name  Last_Name  Age  Department_Region  \
# <class 'float'>            0           0          0  809                  0
# <class 'bool'>             0           0          0    0                  0
# <class 'str'>           1020        1020       1020    0               1020
# <NA>                       0           0          0  211                  0
# <class 'int'>              0           0          0    0                  0
#
#                  Status  Join_Date  Salary  Email  Phone  Performance_Score  \
# <class 'float'>       0          0     996      0      0                  0
# <class 'bool'>        0          0       0      0      0                  0
# <class 'str'>      1020       1020       0   1020      0               1020
# <NA>                  0          0      24      0      0                  0
# <class 'int'>         0          0       0      0   1020                  0
#
#                  Remote_Work
# <class 'float'>            0
# <class 'bool'>          1020
# <class 'str'>              0
# <NA>                       0
# <class 'int'>              0
# -------------------------------------------------------------------------------
# Values Counter
# Employee_ID: <object> BEGIN
# Employee_ID: Has more than 20 values (1020 values)
#
# First_Name: <object> BEGIN
# 	Bob: 133
# 	Alice: 117
# 	Eva: 136
# 	Frank: 142
# 	Charlie: 125
# 	David: 116
# 	Heidi: 111
# 	Grace: 140
# First_Name: <object> END
#
# Last_Name: <object> BEGIN
# 	Davis: 120
# 	Brown: 148
# 	Jones: 131
# 	Williams: 115
# 	Garcia: 136
# 	Johnson: 118
# 	Miller: 116
# 	Smith: 136
# Last_Name: <object> END
#
# Age: <float64> BEGIN
# Age: Has more than 20 values (215 values)
#
# Department_Region: <object> BEGIN
# Department_Region: Has more than 20 values (36 values)
#
# Status: <object> BEGIN
# 	Active: 352
# 	Pending: 356
# 	Inactive: 312
# Status: <object> END
#
# Join_Date: <object> BEGIN
# Join_Date: Has more than 20 values (760 values)
#
# Salary: <float64> BEGIN
# Salary: Has more than 20 values (1002 values)
#
# Email: <object> BEGIN
# Email: Has more than 20 values (64 values)
#
# Phone: <int64> BEGIN
# Phone: Has more than 20 values (1020 values)
#
# Performance_Score: <object> BEGIN
# 	Average: 267
# 	Excellent: 267
# 	Good: 270
# 	Poor: 216
# Performance_Score: <object> END
#
# Remote_Work: <bool> BEGIN
# 	True: 513
# 	False: 507
# Remote_Work: <bool> END

# %%
df_cp1 = df.copy()

# %%
df_cp1 = df_cp1.set_index('Employee_ID')

# %%
df_cp1
# Out:
#             First_Name Last_Name   Age   Department_Region    Status  \
# Employee_ID
# EMP1000            Bob     Davis  25.0   DevOps-California    Active
# EMP1001            Bob     Brown   NaN       Finance-Texas    Active
# EMP1002          Alice     Jones   NaN        Admin-Nevada   Pending
# EMP1003            Eva     Davis  25.0        Admin-Nevada  Inactive
# EMP1004          Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...                ...       ...   ...                 ...       ...
# EMP2015          David    Miller  30.0       HR-California    Active
# EMP2016          David   Johnson  30.0    Cloud Tech-Texas  Inactive
# EMP2017        Charlie  Williams  40.0    Finance-New York    Active
# EMP2018          Alice    Garcia  30.0          HR-Florida  Inactive
# EMP2019          Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#               Join_Date     Salary                         Email       Phone  \
# Employee_ID
# EMP1000        4/2/2021   59767.65         bob.davis@example.com -1651623197
# EMP1001       7/10/2020   65304.66         bob.brown@example.com -1898471390
# EMP1002       12/7/2023   88145.90       alice.jones@example.com -5596363211
# EMP1003      11/27/2021   69450.99         eva.davis@example.com -3476490784
# EMP1004        1/5/2022  109324.61    frank.williams@example.com -1586734256
# ...                 ...        ...                           ...         ...
# EMP2015       8/19/2023        NaN      david.miller@example.com -3546212759
# EMP2016       11/7/2021  100215.06     david.johnson@example.com -2508261122
# EMP2017       10/4/2023  114587.11  charlie.williams@example.com -1261632487
# EMP2018      12/16/2024   71318.79      alice.garcia@example.com -8995729892
# EMP2019       2/22/2021   77764.24       heidi.jones@example.com -7629745492
#
#             Performance_Score  Remote_Work
# Employee_ID
# EMP1000               Average         True
# EMP1001             Excellent         True
# EMP1002                  Good         True
# EMP1003                  Good         True
# EMP1004                  Poor        False
# ...                       ...          ...
# EMP2015                  Good         True
# EMP2016                  Good         True
# EMP2017               Average        False
# EMP2018                  Good         True
# EMP2019               Average        False
#
# [1020 rows x 11 columns]

# %%
lib.has_different_dtypes(df_cp1)
# Out:
#                   has_different_types has_<NA>
# First_Name                      False        0
# Last_Name                       False        0
# Age                             False      211
# Department_Region               False        0
# Status                          False        0
# Join_Date                       False        0
# Salary                          False       24
# Email                           False        0
# Phone                           False        0
# Performance_Score               False        0
# Remote_Work                     False        0

# %%
lib.null_info(df_cp1)
# Out:
# 2/11 columns contain null values
# 235 total null values
# -------------------------------------------------------------------------------
# Column "First_Name" has no null values
# Column "Last_Name" has no null values
# Column "Department_Region" has no null values
# Column "Status" has no null values
# Column "Join_Date" has no null values
# Column "Email" has no null values
# Column "Phone" has no null values
# Column "Performance_Score" has no null values
# Column "Remote_Work" has no null values
# Column "Age" has 211 null values
# Column "Salary" has 24 null values
#
# Risk Rate ---------------------------------------------------------------------
# First_Name           0.000000
# Last_Name            0.000000
# Age                  0.206863
# Department_Region    0.000000
# Status               0.000000
# Join_Date            0.000000
# Salary               0.023529
# Email                0.000000
# Phone                0.000000
# Performance_Score    0.000000
# Remote_Work          0.000000
# dtype: float64
# (              Age     Salary
#  Employee_ID
#  EMP1001       NaN   65304.66
#  EMP1002       NaN   88145.90
#  EMP1006       NaN   96288.43
#  EMP1009       NaN   76561.88
#  EMP1011       NaN   84946.19
#  ...           ...        ...
#  EMP2006       NaN   77821.79
#  EMP2009       NaN   62603.98
#  EMP2012      35.0        NaN
#  EMP2013       NaN  116680.63
#  EMP2015      30.0        NaN
#
#  [233 rows x 2 columns],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [])

# %%
df_cp1['Age']
# Out:
# Employee_ID
# EMP1000    25.0
# EMP1001     NaN
# EMP1002     NaN
# EMP1003    25.0
# EMP1004    25.0
#            ...
# EMP2015    30.0
# EMP2016    30.0
# EMP2017    40.0
# EMP2018    30.0
# EMP2019    30.0
# Name: Age, Length: 1020, dtype: float64

# %%
df_cp1['Age'] = lib.fillnull(df_cp1['Age'], default=0)[0].astype(int)

# %%
df_cp1['Salary'], filler_values = lib.fillnull(df_cp1['Salary'])

# %%
lib.hasnull(df_cp1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_cp1.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Age', 'Department_Region', 'Status',
#        'Join_Date', 'Salary', 'Email', 'Phone', 'Performance_Score',
#        'Remote_Work'],
#       dtype='object')

# %%
for col, series in df_cp1.items():
    log.info(f'{col}: {lib.get_close_matches(series)}')
# Out:
# First_Name: set()
# Last_Name: set()
# Age: set()
# Department_Region: set()
# Status: set()
# Join_Date: {'1/21/2023', '4/11/2020', '11/30/2024', '7/20/2020', '8/19/2020', '7/27/2024', '7/16/2020', '12/22/2020', '5/21/2022', '8/12/2022', '3/13/2023', '4/19/2024', '9/30/2022', '11/26/2022', '2/28/2021', '10/25/2021', '6/5/2020', '9/5/2021', '1/1/2024', '1/29/2020', '9/24/2024', '11/7/2022', '11/3/2023', '7/22/2024', '1/5/2022', '1/11/2024', '2/18/2022', '8/3/2024', '3/1/2022', '11/12/2022', '7/3/2021', '12/5/2023', '11/7/2024', '7/20/2021', '9/19/2020', '1/16/2020', '7/14/2024', '10/4/2020', '5/18/2023', '11/19/2021', '7/27/2023', '4/8/2020', '8/11/2024', '11/2/2021', '7/29/2022', '12/28/2022', '8/28/2021', '7/1/2020', '4/13/2020', '8/24/2023', '9/1/2021', '4/16/2021', '3/19/2021', '1/9/2022', '3/26/2024', '8/21/2021', '10/5/2020', '5/13/2020', '9/17/2022', '2/17/2021', '12/14/2022', '12/25/2024', '1/9/2021', '8/4/2021', '7/16/2024', '4/15/2024', '8/12/2021', '7/4/2022', '1/3/2021', '2/3/2021', '12/5/2022', '4/22/2023', '10/24/2022', '2/22/2020', '7/20/2022', '6/17/2022', '4/22/2020', '7/19/2020', '7/23/2024', '11/27/2021', '9/27/2022', '4/17/2022', '1/2/2021', '9/23/2020', '4/13/2023', '2/20/2020', '10/10/2021', '5/25/2023', '7/28/2023', '11/11/2021', '3/9/2021', '10/25/2024', '1/16/2023', '6/5/2024', '12/7/2022', '12/28/2021', '1/2/2024', '4/9/2020', '12/3/2024', '4/28/2020', '11/21/2023', '1/28/2021', '8/27/2024', '9/11/2024', '9/16/2020', '2/25/2020', '5/19/2021', '3/12/2020', '7/20/2023', '11/21/2020', '8/10/2021', '7/9/2022', '1/25/2021', '2/29/2024', '11/22/2022', '1/12/2020', '5/3/2024', '2/24/2022', '7/31/2020', '7/23/2022', '7/7/2021', '3/15/2022', '11/22/2021', '7/12/2023', '5/25/2021', '5/29/2021', '4/3/2020', '10/4/2024', '3/10/2021', '7/14/2020', '6/17/2020', '11/8/2020', '4/17/2023', '9/5/2024', '7/21/2024', '10/20/2024', '4/30/2023', '2/2/2022', '11/20/2022', '6/13/2023', '8/23/2021', '10/21/2024', '12/8/2023', '4/19/2020', '12/19/2024', '3/18/2021', '2/21/2021', '11/17/2023', '5/30/2022', '12/24/2023', '1/30/2022', '9/8/2024', '8/23/2023', '9/17/2024', '5/23/2023', '8/19/2022', '3/3/2022', '5/29/2020', '5/21/2021', '1/16/2022', '6/13/2021', '12/15/2020', '3/5/2022', '6/27/2024', '11/26/2021', '7/2/2022', '4/28/2024', '9/29/2023', '6/22/2020', '11/1/2022', '2/26/2024', '9/29/2024', '7/6/2023', '1/2/2020', '5/8/2023', '1/5/2021', '2/2/2024', '11/19/2020', '2/8/2022', '3/7/2021', '5/18/2024', '3/21/2023', '4/27/2023', '5/24/2020', '10/14/2024', '1/17/2023', '8/30/2023', '9/10/2021', '3/21/2020', '11/6/2024', '2/22/2022', '4/13/2024', '3/21/2022', '12/13/2023', '2/1/2023', '11/10/2023', '11/29/2023', '7/17/2022', '3/25/2024', '6/12/2022', '6/16/2022', '1/7/2023', '10/15/2023', '11/8/2021', '1/9/2020', '4/1/2022', '11/4/2020', '2/3/2023', '9/8/2023', '4/18/2021', '4/4/2021', '8/14/2022', '4/29/2020', '10/15/2020', '7/18/2022', '9/8/2022', '10/15/2022', '3/31/2024', '6/29/2023', '5/13/2021', '6/13/2022', '10/26/2023', '9/16/2021', '4/6/2023', '3/9/2020', '12/9/2020', '10/5/2024', '8/16/2023', '6/21/2022', '5/2/2024', '9/19/2023', '11/12/2023', '6/2/2023', '6/15/2024', '1/24/2022', '10/28/2022', '8/5/2024', '11/18/2021', '11/30/2023', '4/24/2022', '2/5/2024', '4/16/2022', '8/5/2020', '8/4/2023', '7/31/2022', '6/29/2021', '8/7/2021', '9/20/2023', '3/16/2024', '5/17/2022', '10/29/2022', '1/29/2023', '6/3/2022', '9/11/2020', '11/25/2020', '7/15/2023', '10/11/2021', '3/26/2022', '9/28/2023', '9/28/2020', '7/14/2021', '12/6/2023', '7/1/2021', '5/10/2021', '3/31/2023', '8/3/2022', '12/18/2024', '6/5/2023', '12/21/2022', '3/31/2022', '12/23/2024', '8/13/2024', '5/4/2021', '9/7/2022', '12/11/2021', '10/10/2022', '3/25/2023', '4/5/2024', '10/18/2021', '3/17/2023', '10/14/2023', '10/23/2021', '7/17/2023', '6/16/2020', '2/24/2023', '8/20/2021', '5/31/2022', '1/26/2024', '10/1/2020', '11/17/2021', '8/10/2024', '2/8/2020', '3/13/2021', '9/25/2020', '7/28/2024', '8/28/2023', '5/27/2021', '11/14/2024', '8/14/2021', '2/27/2022', '11/6/2023', '4/30/2020', '6/10/2021', '4/20/2020', '1/30/2024', '9/5/2020', '1/23/2023', '1/22/20 ...
# Salary: set()
# Email: set()
# Phone: set()
# Performance_Score: set()
# Remote_Work: set()

# %%
pd.to_datetime(df_cp1['Join_Date'])
# Out:
# Employee_ID
# EMP1000   2021-04-02
# EMP1001   2020-07-10
# EMP1002   2023-12-07
# EMP1003   2021-11-27
# EMP1004   2022-01-05
#              ...
# EMP2015   2023-08-19
# EMP2016   2021-11-07
# EMP2017   2023-10-04
# EMP2018   2024-12-16
# EMP2019   2021-02-22
# Name: Join_Date, Length: 1020, dtype: datetime64[ns]

# %%
df_cp1['Join_Date'] = pd.to_datetime(df_cp1['Join_Date'])

# %%
df_cp1
# Out:
#             First_Name Last_Name  Age   Department_Region    Status  \
# Employee_ID
# EMP1000            Bob     Davis   25   DevOps-California    Active
# EMP1001            Bob     Brown    0       Finance-Texas    Active
# EMP1002          Alice     Jones    0        Admin-Nevada   Pending
# EMP1003            Eva     Davis   25        Admin-Nevada  Inactive
# EMP1004          Frank  Williams   25  Cloud Tech-Florida    Active
# ...                ...       ...  ...                 ...       ...
# EMP2015          David    Miller   30       HR-California    Active
# EMP2016          David   Johnson   30    Cloud Tech-Texas  Inactive
# EMP2017        Charlie  Williams   40    Finance-New York    Active
# EMP2018          Alice    Garcia   30          HR-Florida  Inactive
# EMP2019          Heidi     Jones   30     DevOps-Illinois   Pending
#
#              Join_Date         Salary                         Email  \
# Employee_ID
# EMP1000     2021-04-02   59767.650000         bob.davis@example.com
# EMP1001     2020-07-10   65304.660000         bob.brown@example.com
# EMP1002     2023-12-07   88145.900000       alice.jones@example.com
# EMP1003     2021-11-27   69450.990000         eva.davis@example.com
# EMP1004     2022-01-05  109324.610000    frank.williams@example.com
# ...                ...            ...                           ...
# EMP2015     2023-08-19   85155.056396      david.miller@example.com
# EMP2016     2021-11-07  100215.060000     david.johnson@example.com
# EMP2017     2023-10-04  114587.110000  charlie.williams@example.com
# EMP2018     2024-12-16   71318.790000      alice.garcia@example.com
# EMP2019     2021-02-22   77764.240000       heidi.jones@example.com
#
#                   Phone Performance_Score  Remote_Work
# Employee_ID
# EMP1000     -1651623197           Average         True
# EMP1001     -1898471390         Excellent         True
# EMP1002     -5596363211              Good         True
# EMP1003     -3476490784              Good         True
# EMP1004     -1586734256              Poor        False
# ...                 ...               ...          ...
# EMP2015     -3546212759              Good         True
# EMP2016     -2508261122              Good         True
# EMP2017     -1261632487           Average        False
# EMP2018     -8995729892              Good         True
# EMP2019     -7629745492           Average        False
#
# [1020 rows x 11 columns]

# %%
df_cp1['Performance_Score'].unique()
# Out:
# array(['Average', 'Excellent', 'Good', 'Poor'], dtype=object)

# %%
df_cp1['Performance_Score'] = df_cp1['Performance_Score'].str.replace('Excellent', '4')
df_cp1['Performance_Score'] = df_cp1['Performance_Score'].str.replace('Good', '3')
df_cp1['Performance_Score'] = df_cp1['Performance_Score'].str.replace('Average', '2')
df_cp1['Performance_Score'] = df_cp1['Performance_Score'].str.replace('Poor', '1')
df_cp1['Performance_Score'] = df_cp1['Performance_Score'].astype(int)

# %%
df_cp1['Performance_Score']
# Out:
# Employee_ID
# EMP1000    2
# EMP1001    4
# EMP1002    3
# EMP1003    3
# EMP1004    1
#           ..
# EMP2015    3
# EMP2016    3
# EMP2017    2
# EMP2018    3
# EMP2019    2
# Name: Performance_Score, Length: 1020, dtype: int64

# %%
df_clean_data = df_cp1.copy()

# %%
lib.export_data(filename, df_clean_data)
# Out:
# PosixPath('/Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/messy_employee_dataset/messy_employee_dataset_CLEAN.csv')
