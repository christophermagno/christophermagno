# %% [markdown]
# # Cleaning Messy Chicago Traffic Crashes Dataset
# Dataset from https://catalog.data.gov/dataset/traffic-crashes-crashes

# %%
import pandas as pd
import importlib

import lib

importlib.reload(lib)

log = lib.logger.getLogger(__name__)

# %% [markdown]
# # Read dataset

# %%
filename = 'chicago_traffic_crashes.csv'
df = lib.tools.read_data(filename, sep=',', encoding='ascii')
# Out:
# Encoding: ascii

# %% [markdown]
# ## Getting the general info to see what we're working with

# %%
log.info(f'General Info {df.info()}')
log.info(f'General Info {df.shape}')
# Out:
# General Info None
# General Info (984012, 48)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984012 entries, 0 to 984011
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH_RECORD_ID                984012 non-null  object
#  1   CRASH_DATE_EST_I               71715 non-null   object
#  2   CRASH_DATE                     984012 non-null  object
#  3   POSTED_SPEED_LIMIT             984012 non-null  int64
#  4   TRAFFIC_CONTROL_DEVICE         984012 non-null  object
#  5   DEVICE_CONDITION               984012 non-null  object
#  6   WEATHER_CONDITION              984012 non-null  object
#  7   LIGHTING_CONDITION             984012 non-null  object
#  8   FIRST_CRASH_TYPE               984012 non-null  object
#  9   TRAFFICWAY_TYPE                984012 non-null  object
#  10  LANE_CNT                       199029 non-null  float64
#  11  ALIGNMENT                      984012 non-null  object
#  12  ROADWAY_SURFACE_COND           984012 non-null  object
#  13  ROAD_DEFECT                    984012 non-null  object
#  14  REPORT_TYPE                    951788 non-null  object
#  15  CRASH_TYPE                     984012 non-null  object
#  16  INTERSECTION_RELATED_I         226145 non-null  object
#  17  NOT_RIGHT_OF_WAY_I             44319 non-null   object
#  18  HIT_AND_RUN_I                  308770 non-null  object
#  19  DAMAGE                         984012 non-null  object
#  20  DATE_POLICE_NOTIFIED           984012 non-null  object
#  21  PRIM_CONTRIBUTORY_CAUSE        984012 non-null  object
#  22  SEC_CONTRIBUTORY_CAUSE         984012 non-null  object
#  23  STREET_NO                      984012 non-null  int64
#  24  STREET_DIRECTION               984008 non-null  object
#  25  STREET_NAME                    984011 non-null  object
#  26  BEAT_OF_OCCURRENCE             984007 non-null  float64
#  27  PHOTOS_TAKEN_I                 13874 non-null   object
#  28  STATEMENTS_TAKEN_I             23212 non-null   object
#  29  DOORING_I                      3134 non-null    object
#  30  WORK_ZONE_I                    5377 non-null    object
#  31  WORK_ZONE_TYPE                 4114 non-null    object
#  32  WORKERS_PRESENT_I              1381 non-null    object
#  33  NUM_UNITS                      984012 non-null  int64
#  34  MOST_SEVERE_INJURY             981861 non-null  object
#  35  INJURIES_TOTAL                 981875 non-null  float64
#  36  INJURIES_FATAL                 981875 non-null  float64
#  37  INJURIES_INCAPACITATING        981875 non-null  float64
#  38  INJURIES_NON_INCAPACITATING    981875 non-null  float64
#  39  INJURIES_REPORTED_NOT_EVIDENT  981875 non-null  float64
#  40  INJURIES_NO_INDICATION         981875 non-null  float64
#  41  INJURIES_UNKNOWN               981875 non-null  float64
#  42  CRASH_HOUR                     984012 non-null  int64
#  43  CRASH_DAY_OF_WEEK              984012 non-null  int64
#  44  CRASH_MONTH                    984012 non-null  int64
#  45  LATITUDE                       976612 non-null  float64
#  46  LONGITUDE                      976612 non-null  float64
#  47  LOCATION                       976612 non-null  object
# dtypes: float64(11), int64(6), object(31)
# memory usage: 360.4+ MB

# %% [markdown]
# ### Checking for null indices and rows

# %%
null_indices, null_rows, null_columns = lib.tools.null_info(df)
# Out:
# 26/48 columns contain null values
# 9994606 total null values

# %% [markdown]
# ## No rows or columns that are ALL null. Moving onto cleaning columns.

# %% [markdown]
# ## Creating a backup

# %%
df_cp1 = df.copy()

# %% [markdown]
# # Processing NaN Values

# %%
df_cp1.columns
# Out:
# Index(['CRASH_RECORD_ID', 'CRASH_DATE_EST_I', 'CRASH_DATE',
#        'POSTED_SPEED_LIMIT', 'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION',
#        'WEATHER_CONDITION', 'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE',
#        'TRAFFICWAY_TYPE', 'LANE_CNT', 'ALIGNMENT', 'ROADWAY_SURFACE_COND',
#        'ROAD_DEFECT', 'REPORT_TYPE', 'CRASH_TYPE', 'INTERSECTION_RELATED_I',
#        'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'DAMAGE', 'DATE_POLICE_NOTIFIED',
#        'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO',
#        'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE',
#        'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I',
#        'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'NUM_UNITS',
#        'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
#        'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING',
#        'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION',
#        'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH',
#        'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %% [markdown]
# ## Checking for NaN and Non-NaN columns

# %%
# Create a null and non_null columns list
non_null_columns = lib.tools.notnull(df_cp1).columns
null_columns = lib.tools.hasnull(df_cp1).columns

log.info(non_null_columns)
log.info(null_columns)
# Out:
# Index(['CRASH_RECORD_ID', 'CRASH_DATE', 'POSTED_SPEED_LIMIT',
#        'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION', 'WEATHER_CONDITION',
#        'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE',
#        'ALIGNMENT', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'CRASH_TYPE',
#        'DAMAGE', 'DATE_POLICE_NOTIFIED', 'PRIM_CONTRIBUTORY_CAUSE',
#        'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO', 'NUM_UNITS', 'CRASH_HOUR',
#        'CRASH_DAY_OF_WEEK', 'CRASH_MONTH'],
#       dtype='object')
# Index(['CRASH_DATE_EST_I', 'LANE_CNT', 'REPORT_TYPE', 'INTERSECTION_RELATED_I',
#        'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'STREET_DIRECTION',
#        'STREET_NAME', 'BEAT_OF_OCCURRENCE', 'PHOTOS_TAKEN_I',
#        'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE',
#        'WORKERS_PRESENT_I', 'MOST_SEVERE_INJURY', 'INJURIES_TOTAL',
#        'INJURIES_FATAL', 'INJURIES_INCAPACITATING',
#        'INJURIES_NON_INCAPACITATING', 'INJURIES_REPORTED_NOT_EVIDENT',
#        'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN', 'LATITUDE', 'LONGITUDE',
#        'LOCATION'],
#       dtype='object')

# %% [markdown]
# ## Checking for columns whose values are 75% or more NaN

# %%
# Get columns that mostly have NaN values. Will need to look at these closer.
high_risk = lib.tools.data_risks_rate(df_cp1, err_rate=.75)

# %% [markdown]
# Taking a look at the high risk columns

# %%
high_risk
# Out:
# CRASH_DATE_EST_I          0.927120
# LANE_CNT                  0.797737
# INTERSECTION_RELATED_I    0.770181
# NOT_RIGHT_OF_WAY_I        0.954961
# PHOTOS_TAKEN_I            0.985901
# STATEMENTS_TAKEN_I        0.976411
# DOORING_I                 0.996815
# WORK_ZONE_I               0.994536
# WORK_ZONE_TYPE            0.995819
# WORKERS_PRESENT_I         0.998597
# dtype: float64

# %% [markdown]
# ## Removing data that is not useable

# %%
df_cp1 = df_cp1.drop(high_risk.keys(), axis=1)

# %% [markdown]
# ## Filling the rest of the NaN values with filler values

# %%
df_cp1, filler_values = lib.tools.fillnull(df_cp1)

# %% [markdown]
# ## Creating a backup

# %%
df_cp2 = df_cp1.copy()

# %%
df_cp2.columns
# Out:
# Index(['CRASH_RECORD_ID', 'CRASH_DATE', 'POSTED_SPEED_LIMIT',
#        'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION', 'WEATHER_CONDITION',
#        'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE',
#        'ALIGNMENT', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'REPORT_TYPE',
#        'CRASH_TYPE', 'HIT_AND_RUN_I', 'DAMAGE', 'DATE_POLICE_NOTIFIED',
#        'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO',
#        'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE', 'NUM_UNITS',
#        'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
#        'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING',
#        'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION',
#        'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH',
#        'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %% [markdown]
# # Checking and Validating data

# %%
df_cp2.loc[:, 'CRASH_DATE']
# Out:
# 0         01/14/2025 12:25:00 PM
# 1         05/23/2025 09:30:00 AM
# 2         04/05/2025 08:00:00 PM
# 3         05/23/2025 09:15:00 AM
# 4         01/14/2025 08:00:00 AM
#                    ...
# 984007    08/07/2025 06:40:00 PM
# 984008    08/16/2025 11:50:00 PM
# 984009    08/17/2025 02:00:00 PM
# 984010    08/18/2025 12:08:00 AM
# 984011    08/18/2025 12:24:00 AM
# Name: CRASH_DATE, Length: 984012, dtype: object

# %% [markdown]
# Unifying proper formatting for pd.Timestamp data type

# %%
df_cp2.loc[:, 'POSTED_SPEED_LIMIT']
# Out:
# 0         30
# 1         30
# 2         30
# 3         30
# 4         30
#           ..
# 984007    30
# 984008    30
# 984009    30
# 984010    30
# 984011    30
# Name: POSTED_SPEED_LIMIT, Length: 984012, dtype: int64

# %% [markdown]
# Quick check of values

# %%
minimum = df_cp2.loc[:, 'POSTED_SPEED_LIMIT'].min()
maximum = df_cp2.loc[:, 'POSTED_SPEED_LIMIT'].max()
average = df_cp2.loc[:, 'POSTED_SPEED_LIMIT'].mean()
log.info(f'Min/Max/Avg POSTED_SPEED_LIMIT {minimum}/{maximum}/{average}')
# Out:
# Min/Max/Avg POSTED_SPEED_LIMIT 0/99/28.423204188566807

# %% [markdown]
# Valid values, no need to clean this column

# %% [markdown]
# Checking for categories

# %%
df_cp2.loc[:, 'DEVICE_CONDITION'].unique()
# Out:
# array(['FUNCTIONING PROPERLY', 'UNKNOWN', 'NO CONTROLS',
#        'FUNCTIONING IMPROPERLY', 'OTHER', 'NOT FUNCTIONING',
#        'WORN REFLECTIVE MATERIAL', 'MISSING'], dtype=object)

# %%
df_cp2.loc[:, 'WEATHER_CONDITION'].unique()
# Out:
# array(['SNOW', 'UNKNOWN', 'CLEAR', 'RAIN', 'CLOUDY/OVERCAST',
#        'FREEZING RAIN/DRIZZLE', 'SLEET/HAIL', 'OTHER', 'BLOWING SNOW',
#        'SEVERE CROSS WIND GATE', 'FOG/SMOKE/HAZE',
#        'BLOWING SAND, SOIL, DIRT'], dtype=object)

# %% [markdown]
# To keep with current formatting, switching 'BLOWING SAND, SOIL, DIRT' to '/'

# %%
df_cp2.loc[:, 'WEATHER_CONDITION'] = df_cp2.loc[:, 'WEATHER_CONDITION'].str.replace(', ', '/')
df_cp2.loc[:, 'WEATHER_CONDITION'].unique()
# Out:
# array(['SNOW', 'UNKNOWN', 'CLEAR', 'RAIN', 'CLOUDY/OVERCAST',
#        'FREEZING RAIN/DRIZZLE', 'SLEET/HAIL', 'OTHER', 'BLOWING SNOW',
#        'SEVERE CROSS WIND GATE', 'FOG/SMOKE/HAZE',
#        'BLOWING SAND/SOIL/DIRT'], dtype=object)

# %%
df_cp2.loc[:, 'LIGHTING_CONDITION'].unique()
# Out:
# array(['DAYLIGHT', 'UNKNOWN', 'DARKNESS, LIGHTED ROAD', 'DARKNESS',
#        'DUSK', 'DAWN'], dtype=object)

# %%
df_cp2.loc[:, 'FIRST_CRASH_TYPE'].unique()
# Out:
# array(['SIDESWIPE SAME DIRECTION', 'TURNING', 'PARKED MOTOR VEHICLE',
#        'PEDALCYCLIST', 'REAR END', 'ANGLE',
#        'SIDESWIPE OPPOSITE DIRECTION', 'FIXED OBJECT', 'PEDESTRIAN',
#        'REAR TO SIDE', 'HEAD ON', 'REAR TO FRONT', 'OTHER OBJECT',
#        'OTHER NONCOLLISION', 'REAR TO REAR', 'OVERTURNED', 'ANIMAL',
#        'TRAIN'], dtype=object)

# %%
df_cp2['TRAFFICWAY_TYPE'].unique()
# Out:
# array(['DIVIDED - W/MEDIAN (NOT RAISED)', 'NOT DIVIDED', 'FOUR WAY',
#        'DIVIDED - W/MEDIAN BARRIER', 'ONE-WAY', 'PARKING LOT', 'UNKNOWN',
#        'T-INTERSECTION', 'OTHER', 'TRAFFIC ROUTE', 'DRIVEWAY',
#        'UNKNOWN INTERSECTION TYPE', 'ALLEY', 'Y-INTERSECTION',
#        'FIVE POINT, OR MORE', 'L-INTERSECTION', 'RAMP',
#        'CENTER TURN LANE', 'NOT REPORTED', 'ROUNDABOUT'], dtype=object)

# %%
df_cp2['ALIGNMENT'].unique()
# Out:
# array(['STRAIGHT AND LEVEL', 'STRAIGHT ON GRADE', 'STRAIGHT ON HILLCREST',
#        'CURVE, LEVEL', 'CURVE ON GRADE', 'CURVE ON HILLCREST'],
#       dtype=object)

# %%
df_cp2['ROADWAY_SURFACE_COND'].unique()
# Out:
# array(['SNOW OR SLUSH', 'UNKNOWN', 'DRY', 'WET', 'ICE', 'OTHER',
#        'SAND, MUD, DIRT'], dtype=object)

# %%
df_cp2['ROAD_DEFECT'].unique()
# Out:
# array(['NO DEFECTS', 'UNKNOWN', 'SHOULDER DEFECT', 'WORN SURFACE',
#        'RUT, HOLES', 'OTHER', 'DEBRIS ON ROADWAY'], dtype=object)

# %%
df_cp2.columns
# Out:
# Index(['CRASH_RECORD_ID', 'CRASH_DATE', 'POSTED_SPEED_LIMIT',
#        'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION', 'WEATHER_CONDITION',
#        'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE',
#        'ALIGNMENT', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'REPORT_TYPE',
#        'CRASH_TYPE', 'HIT_AND_RUN_I', 'DAMAGE', 'DATE_POLICE_NOTIFIED',
#        'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO',
#        'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE', 'NUM_UNITS',
#        'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
#        'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING',
#        'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION',
#        'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH',
#        'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
df_cp2['REPORT_TYPE'].unique()
# Out:
# array(['ON SCENE', 'NOT ON SCENE (DESK REPORT)', 'Not Available',
#        'AMENDED'], dtype=object)

# %%
df_cp2['CRASH_TYPE'].unique()
# Out:
# array(['NO INJURY / DRIVE AWAY', 'INJURY AND / OR TOW DUE TO CRASH'],
#       dtype=object)

# %%
df_cp2['HIT_AND_RUN_I'].unique()
# Out:
# array(['Y', 'Not Available', 'N'], dtype=object)

# %%
df_cp2['DAMAGE'].unique()
# Out:
# array(['$501 - $1,500', 'OVER $1,500', '$500 OR LESS'], dtype=object)

# %%
df_cp2['DATE_POLICE_NOTIFIED'].unique()
# Out:
# array(['01/14/2025 12:38:00 PM', '05/27/2025 10:40:00 AM',
#        '04/05/2025 09:23:00 PM', ..., '08/16/2025 11:55:00 PM',
#        '08/18/2025 12:09:00 AM', '08/18/2025 12:28:00 AM'],
#       shape=(744929,), dtype=object)

# %%
df_cp2['PRIM_CONTRIBUTORY_CAUSE'].unique()
# Out:
# array(['IMPROPER TURNING/NO SIGNAL', 'IMPROPER OVERTAKING/PASSING',
#        'UNABLE TO DETERMINE', 'FOLLOWING TOO CLOSELY',
#        'DISREGARDING TRAFFIC SIGNALS', 'IMPROPER LANE USAGE',
#        'FAILING TO YIELD RIGHT-OF-WAY', 'NOT APPLICABLE',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'FAILING TO REDUCE SPEED TO AVOID CRASH',
#        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE', 'WEATHER',
#        'DISREGARDING STOP SIGN', 'IMPROPER BACKING',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'TURNING RIGHT ON RED', 'PHYSICAL CONDITION OF DRIVER',
#        'EQUIPMENT - VEHICLE CONDITION', 'DRIVING ON WRONG SIDE/WRONG WAY',
#        'DISREGARDING ROAD MARKINGS',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'DISTRACTION - FROM OUTSIDE VEHICLE',
#        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)',
#        'TEXTING', 'ROAD CONSTRUCTION/MAINTENANCE',
#        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
#        'DISTRACTION - FROM INSIDE VEHICLE',
#        'CELL PHONE USE OTHER THAN TEXTING', 'ANIMAL',
#        'DISREGARDING OTHER TRAFFIC SIGNS', 'RELATED TO BUS STOP',
#        'OBSTRUCTED CROSSWALKS', 'DISREGARDING YIELD SIGN',
#        'PASSING STOPPED SCHOOL BUS',
#        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'EXCEEDING AUTHORIZED SPEED LIMIT',
#        'EXCEEDING SAFE SPEED FOR CONDITIONS'], dtype=object)

# %%
df_cp2['SEC_CONTRIBUTORY_CAUSE'].unique()
# Out:
# array(['IMPROPER OVERTAKING/PASSING', 'UNABLE TO DETERMINE',
#        'FOLLOWING TOO CLOSELY', 'NOT APPLICABLE',
#        'FAILING TO YIELD RIGHT-OF-WAY',
#        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE', 'WEATHER',
#        'FAILING TO REDUCE SPEED TO AVOID CRASH',
#        'PHYSICAL CONDITION OF DRIVER', 'IMPROPER LANE USAGE',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'IMPROPER BACKING', 'DISREGARDING STOP SIGN',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'IMPROPER TURNING/NO SIGNAL', 'ROAD CONSTRUCTION/MAINTENANCE',
#        'DRIVING ON WRONG SIDE/WRONG WAY', 'DISREGARDING TRAFFIC SIGNALS',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#        'EQUIPMENT - VEHICLE CONDITION',
#        'CELL PHONE USE OTHER THAN TEXTING',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'DISTRACTION - FROM OUTSIDE VEHICLE',
#        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS', 'TEXTING',
#        'TURNING RIGHT ON RED', 'RELATED TO BUS STOP', 'ANIMAL',
#        'DISTRACTION - FROM INSIDE VEHICLE',
#        'DISREGARDING OTHER TRAFFIC SIGNS', 'DISREGARDING YIELD SIGN',
#        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
#        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)',
#        'PASSING STOPPED SCHOOL BUS', 'DISREGARDING ROAD MARKINGS',
#        'OBSTRUCTED CROSSWALKS',
#        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'EXCEEDING SAFE SPEED FOR CONDITIONS',
#        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'EXCEEDING AUTHORIZED SPEED LIMIT'], dtype=object)

# %%
df_cp2['STREET_NO']
# Out:
# 0         6352
# 1         3555
# 2         1005
# 3         2901
# 4         4001
#           ...
# 984007    7137
# 984008    5001
# 984009     555
# 984010    2034
# 984011    9620
# Name: STREET_NO, Length: 984012, dtype: int64

# %%
df_cp2['STREET_DIRECTION'].unique()
# Out:
# array(['N', 'W', 'S', 'E', 'Not Available'], dtype=object)

# %%
df_cp2['STREET_DIRECTION'].value_counts()['Not Available']
# Out:
# np.int64(4)

# %%
df_cp2['BEAT_OF_OCCURRENCE']
# Out:
# 0         2433.0
# 1         1921.0
# 2         1121.0
# 3         1211.0
# 4         2211.0
#            ...
# 984007    2411.0
# 984008     813.0
# 984009     915.0
# 984010    1424.0
# 984011     432.0
# Name: BEAT_OF_OCCURRENCE, Length: 984012, dtype: float64

# %%
df_cp2['NUM_UNITS'].unique()
# Out:
# array([ 2,  1,  5,  3,  4,  6,  7, 10,  8, 14, 12, 18, 11,  9, 16, 13, 15])

# %%
df_cp2['MOST_SEVERE_INJURY'].unique()
# Out:
# array(['NO INDICATION OF INJURY', 'NONINCAPACITATING INJURY',
#        'REPORTED, NOT EVIDENT', 'INCAPACITATING INJURY', 'FATAL',
#        'Not Available'], dtype=object)

# %%
df_cp2['INJURIES_TOTAL'].unique()
# Out:
# array([ 0.        ,  1.        ,  2.        ,  3.        ,  5.        ,
#         6.        ,  4.        ,  1.19713507,  7.        , 11.        ,
#         8.        ,  9.        , 19.        , 15.        , 10.        ,
#        21.        , 17.        , 12.        , 14.        , 13.        ,
#        16.        ])

# %%
df_cp2['INJURIES_FATAL'].unique()
# Out:
# array([0.        , 1.        , 1.00115697, 2.        , 3.        ,
#        4.        ])

# %%
df_cp2['INJURIES_INCAPACITATING'].unique()
# Out:
# array([ 0.        ,  1.        ,  2.        ,  1.01936397,  3.        ,
#         5.        ,  4.        ,  6.        ,  7.        , 10.        ,
#         8.        ])

# %%
sorted(df_cp2['INJURIES_NON_INCAPACITATING'].astype(int).unique())
# Out:
# [np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(18),
#  np.int64(19),
#  np.int64(21)]

# %%
sorted(df_cp2['INJURIES_REPORTED_NOT_EVIDENT'].astype(int).unique())
# Out:
# [np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(15),
#  np.int64(19)]

# %%
sorted(df_cp2['INJURIES_NO_INDICATION'].astype(int).unique())
# Out:
# [np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(18),
#  np.int64(19),
#  np.int64(20),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(34),
#  np.int64(35),
#  np.int64(36),
#  np.int64(37),
#  np.int64(38),
#  np.int64(39),
#  np.int64(40),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(45),
#  np.int64(46),
#  np.int64(48),
#  np.int64(49),
#  np.int64(50),
#  np.int64(61)]

# %%
sorted(df_cp2['INJURIES_UNKNOWN'].astype(int).unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
df_cp2['CRASH_HOUR'].unique() > 24
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
df_cp2['CRASH_DAY_OF_WEEK'].unique() > 7
# Out:
# array([False, False, False, False, False, False, False])

# %%
df_cp2['CRASH_MONTH'].unique() > 12
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
df_cp2['LATITUDE']
# Out:
# 0         41.997808
# 1         41.946529
# 2         41.899325
# 3         41.902793
# 4         41.691207
#             ...
# 984007    42.012120
# 984008    41.778225
# 984009    41.838002
# 984010    41.904205
# 984011    41.720684
# Name: LATITUDE, Length: 984012, dtype: float64

# %%
df_cp2['LONGITUDE']
# Out:
# 0        -87.655770
# 1        -87.688106
# 2        -87.715074
# 3        -87.699412
# 4        -87.720555
#             ...
# 984007   -87.690100
# 984008   -87.747206
# 984009   -87.641182
# 984010   -87.678698
# 984011   -87.536644
# Name: LONGITUDE, Length: 984012, dtype: float64

# %%
df_cp2['LOCATION']
# Out:
# 0         POINT (-87.655770494712 41.997807727633)
# 1         POINT (-87.688106391039 41.946529480518)
# 2         POINT (-87.715074373867 41.899324573751)
# 3         POINT (-87.699412181285 41.902792968177)
# 4         POINT (-87.720554863466 41.691206664451)
#                             ...
# 984007    POINT (-87.690099690923 42.012120373394)
# 984008    POINT (-87.747206294662 41.778224612839)
# 984009    POINT (-87.641182383332 41.838001538617)
# 984010    POINT (-87.678698087004 41.904205053083)
# 984011    POINT (-87.536644107447 41.720683731954)
# Name: LOCATION, Length: 984012, dtype: object

# %% [markdown]
# ## Creating lists to process

# %%
to_drop = [
    'CRASH_RECORD_ID',
    'STREET_NAME',
    'STREET_NO',
    'STREET_DIRECTION',
    'BEAT_OF_OCCURRENCE',
    'MOST_SEVERE_INJURY', # Repeated in other INJURY_* columns
    'CRASH_HOUR',  # repeated in CRASH_DATE
    'CRASH_DAY_OF_WEEK',  # repeated in CRASH_DATE
    'CRASH_MONTH',  # repeated in CRASH_DATE
    'NUM_UNITS', # Would need clarification what this means
    'LOCATION'
]

# Convert to Timestamp
to_datetime = [
    'CRASH_DATE',
    'DATE_POLICE_NOTIFIED',
]

to_consolidate = [
    'WEATHER_CONDITION',
    'TRAFFIC_CONTROL_DEVICE',
    'DEVICE_CONDITION',
    'FIRST_CRASH_TYPE', #?
    'ALIGNMENT,'
    'TRAFFICWAY_TYPE',
    'ROADWAY_SURFACE_COND',
    'ROAD_DEFECT',
    'PRIM_CONTRIBUTORY_CAUSE',
    'SEC_CONTRIBUTORY_CAUSE',
    'ROADWAY_SURFACE_COND'

]

to_bools_manual = [
    'REPORT_TYPE', # Change to ON_SCENE
    'CRASH_TYPE', # Change to REPORTABLE
    'HIT_AND_RUN_I'
]

to_ints_manual = [
    'DAMAGE'
]

to_ints = [
    'INJURIES_TOTAL',
    'INJURIES_FATAL',
    'INJURIES_INCAPACITATING',
    'INJURIES_NON_INCAPACITATING',
    'INJURIES_REPORTED_NOT_EVIDENT',
    'INJURIES_NO_INDICATION'
]

# No need to check these
valid = [
    'POSTED_SPEED_LIMIT',
    'LIGHTING_CONDITION',
    'LATITUDE',
    'LONGITUDE',
]

keys2 = to_consolidate + to_bools_manual + to_ints_manual + to_ints + to_datetime + to_drop + valid
diff = set(df_cp2.columns).difference(set(keys2))
log.debug(f'Diff {diff}: {df_cp2.shape[1]}/{len(keys2)}')
# Out:
# Diff {'INJURIES_UNKNOWN', 'ALIGNMENT', 'TRAFFICWAY_TYPE'}: 38/37

# %% [markdown]
# ## Creating a backup

# %%
df_cp3 = df_cp2.copy()

# %% [markdown]
# ## Dropping unneeded Columns

# %%
df_cp3 = df_cp3.drop(to_drop, axis=1)

# %% [markdown]
# # Begin Cleaning Process
#
# ## Stripping whitespaces from DataFrame

# %%
df_cp3 = lib.tools.strip_whitespaces(df_cp3)

# %% [markdown]
# ## Converting Datetime columns

# %%
for column in to_datetime:
    df_cp3[column] = pd.to_datetime(df_cp3.loc[:, column], format='%m/%d/%Y %I:%M:%S %p')

# %%
df_cp3[to_datetime]
# Out:
#                 CRASH_DATE DATE_POLICE_NOTIFIED
# 0      2025-01-14 12:25:00  2025-01-14 12:38:00
# 1      2025-05-23 09:30:00  2025-05-27 10:40:00
# 2      2025-04-05 20:00:00  2025-04-05 21:23:00
# 3      2025-05-23 09:15:00  2025-05-23 09:16:00
# 4      2025-01-14 08:00:00  2025-01-14 08:45:00
# ...                    ...                  ...
# 984007 2025-08-07 18:40:00  2025-08-08 15:30:00
# 984008 2025-08-16 23:50:00  2025-08-16 23:55:00
# 984009 2025-08-17 14:00:00  2025-08-18 15:30:00
# 984010 2025-08-18 00:08:00  2025-08-18 00:09:00
# 984011 2025-08-18 00:24:00  2025-08-18 00:28:00
#
# [984012 rows x 2 columns]

# %% [markdown]
# ## Converting Ints columns

# %%
df_cp3['DAMAGE']
# Out:
# 0         $501 - $1,500
# 1           OVER $1,500
# 2           OVER $1,500
# 3          $500 OR LESS
# 4           OVER $1,500
#               ...
# 984007    $501 - $1,500
# 984008      OVER $1,500
# 984009     $500 OR LESS
# 984010      OVER $1,500
# 984011      OVER $1,500
# Name: DAMAGE, Length: 984012, dtype: object

# %%
# Converting to ints
df_cp3['DAMAGE'] = df_cp3['DAMAGE'].replace('$500 OR LESS', 0)
df_cp3['DAMAGE'] = df_cp3['DAMAGE'].replace('$501 - $1,500', 1)
df_cp3['DAMAGE'] = df_cp3['DAMAGE'].replace('OVER $1,500', 2)
df_cp3['DAMAGE'].astype(int)
# Out:
# /var/folders/_9/nyjys43x4nv6dxyk3y75vzh80000gn/T/ipykernel_2961/2964060824.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cp3['DAMAGE'] = df_cp3['DAMAGE'].replace('OVER $1,500', 2)
# 0         1
# 1         2
# 2         2
# 3         0
# 4         2
#          ..
# 984007    1
# 984008    2
# 984009    0
# 984010    2
# 984011    2
# Name: DAMAGE, Length: 984012, dtype: int64

# %%
for column in to_ints:
    df_cp3[column] = df_cp3[column].astype(int)

# %% [markdown]
# ## Converting Bools columns
# -1 for Not Available
# 0 for False
# 1 for True

# %% [markdown]
# Renaming 'REPORT_TYPE' to 'ON_SCENE'

# %%
df_cp3['REPORT_TYPE'].unique()
# Out:
# array(['ON SCENE', 'NOT ON SCENE (DESK REPORT)', 'Not Available',
#        'AMENDED'], dtype=object)

# %% [markdown]
# Change to ON_SCENE

# %%
df_cp3.loc[:, 'REPORT_TYPE'] = df_cp3['REPORT_TYPE'].replace(
    {
        'ON SCENE': 1,
        'NOT ON SCENE (DESK REPORT)': 0,
        'Not Available': -1,
     }
)

# %%
df_cp3 = df_cp3.rename({'REPORT_TYPE': 'ON_SCENE'}, axis=1)
df_cp3.loc[:, 'ON_SCENE']
# Out:
# 0          1
# 1          0
# 2          1
# 3          1
# 4          0
#           ..
# 984007     0
# 984008     1
# 984009     0
# 984010    -1
# 984011     1
# Name: ON_SCENE, Length: 984012, dtype: object

# %%
df_cp3.columns
# Out:
# Index(['CRASH_DATE', 'POSTED_SPEED_LIMIT', 'TRAFFIC_CONTROL_DEVICE',
#        'DEVICE_CONDITION', 'WEATHER_CONDITION', 'LIGHTING_CONDITION',
#        'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE', 'ALIGNMENT',
#        'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'ON_SCENE', 'CRASH_TYPE',
#        'HIT_AND_RUN_I', 'DAMAGE', 'DATE_POLICE_NOTIFIED',
#        'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'INJURIES_TOTAL',
#        'INJURIES_FATAL', 'INJURIES_INCAPACITATING',
#        'INJURIES_NON_INCAPACITATING', 'INJURIES_REPORTED_NOT_EVIDENT',
#        'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %% [markdown]
# Renaming to REPORTABLE

# %%
df_cp3['CRASH_TYPE'].unique()
# Out:
# array(['NO INJURY / DRIVE AWAY', 'INJURY AND / OR TOW DUE TO CRASH'],
#       dtype=object)

# %%
df_cp3.loc[:, 'CRASH_TYPE'] = df_cp3['CRASH_TYPE'].replace(
    {
        'NO INJURY / DRIVE AWAY': False,
        'INJURY AND / OR TOW DUE TO CRASH': True,
     }
)
# Out:
# /var/folders/_9/nyjys43x4nv6dxyk3y75vzh80000gn/T/ipykernel_2961/3714322767.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cp3.loc[:, 'CRASH_TYPE'] = df_cp3['CRASH_TYPE'].replace(

# %%
df_cp3 = df_cp3.rename({'CRASH_TYPE': 'REPORTABLE'}, axis=1)
df_cp3.loc[:, 'REPORTABLE']
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 984007    False
# 984008     True
# 984009    False
# 984010     True
# 984011     True
# Name: REPORTABLE, Length: 984012, dtype: object

# %% [markdown]
# Renaming to HIT_AND_RUN

# %%
df_cp3['HIT_AND_RUN_I'].unique()
# Out:
# array(['Y', 'Not Available', 'N'], dtype=object)

# %%
df_cp3.loc[:, 'HIT_AND_RUN_I'] = df_cp3['HIT_AND_RUN_I'].replace(
    {
        'Not Available': -1,
        'N': 0,
        'Y': 1,
     }
)
df_cp3 = df_cp3.rename({'HIT_AND_RUN_I': 'HIT_AND_RUN'}, axis=1)
df_cp3.loc[:, 'HIT_AND_RUN']
# Out:
# /var/folders/_9/nyjys43x4nv6dxyk3y75vzh80000gn/T/ipykernel_2961/3292695733.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cp3.loc[:, 'HIT_AND_RUN_I'] = df_cp3['HIT_AND_RUN_I'].replace(
# 0          1
# 1          1
# 2          1
# 3         -1
# 4         -1
#           ..
# 984007    -1
# 984008     1
# 984009    -1
# 984010    -1
# 984011    -1
# Name: HIT_AND_RUN, Length: 984012, dtype: object

# %% [markdown]
# ## Creating a backup

# %%
df_cp4 = df_cp3.copy()

# %% [markdown]
# ## Converting Consolidate column
# A manual process

# %%
df_cp4['WEATHER_CONDITION'].unique()
# Out:
# array(['SNOW', 'UNKNOWN', 'CLEAR', 'RAIN', 'CLOUDY/OVERCAST',
#        'FREEZING RAIN/DRIZZLE', 'SLEET/HAIL', 'OTHER', 'BLOWING SNOW',
#        'SEVERE CROSS WIND GATE', 'FOG/SMOKE/HAZE',
#        'BLOWING SAND/SOIL/DIRT'], dtype=object)

# %%
df_cp4['TRAFFIC_CONTROL_DEVICE'].unique()
# Out:
# array(['TRAFFIC SIGNAL', 'STOP SIGN/FLASHER', 'NO CONTROLS', 'UNKNOWN',
#        'OTHER', 'LANE USE MARKING', 'PEDESTRIAN CROSSING SIGN',
#        'OTHER REG. SIGN', 'OTHER WARNING SIGN', 'YIELD', 'SCHOOL ZONE',
#        'FLASHING CONTROL SIGNAL', 'DELINEATORS', 'NO PASSING',
#        'RAILROAD CROSSING GATE', 'POLICE/FLAGMAN', 'RR CROSSING SIGN',
#        'BICYCLE CROSSING SIGN', 'OTHER RAILROAD CROSSING'], dtype=object)

# %%
df_cp4['DEVICE_CONDITION'].unique()
# Out:
# array(['FUNCTIONING PROPERLY', 'UNKNOWN', 'NO CONTROLS',
#        'FUNCTIONING IMPROPERLY', 'OTHER', 'NOT FUNCTIONING',
#        'WORN REFLECTIVE MATERIAL', 'MISSING'], dtype=object)

# %%
df_cp4['DEVICE_CONDITION'] = df_cp4['DEVICE_CONDITION'].replace(
    {
        'FUNCTIONING PROPERLY': True,
        'UNKNOWN': False,
        'NO CONTROLS': False,
        'FUNCTIONING IMPROPERLY': False,
        'OTHER': False,
        'NOT FUNCTIONING': False,
        'WORN REFLECTIVE MATERIAL': False,
        'MISSING': False,
    }
)
df_cp4 = df_cp4.rename({'DEVICE_CONDITION': 'TRAFFIC_DEVICE_FUNCTIONING'}, axis=1)
df_cp4.loc[:, 'TRAFFIC_DEVICE_FUNCTIONING']
# Out:
# /var/folders/_9/nyjys43x4nv6dxyk3y75vzh80000gn/T/ipykernel_2961/1568383276.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cp4['DEVICE_CONDITION'] = df_cp4['DEVICE_CONDITION'].replace(
# 0          True
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 984007     True
# 984008    False
# 984009    False
# 984010    False
# 984011    False
# Name: TRAFFIC_DEVICE_FUNCTIONING, Length: 984012, dtype: bool

# %%
df_cp4['FIRST_CRASH_TYPE'].unique()
# Out:
# array(['SIDESWIPE SAME DIRECTION', 'TURNING', 'PARKED MOTOR VEHICLE',
#        'PEDALCYCLIST', 'REAR END', 'ANGLE',
#        'SIDESWIPE OPPOSITE DIRECTION', 'FIXED OBJECT', 'PEDESTRIAN',
#        'REAR TO SIDE', 'HEAD ON', 'REAR TO FRONT', 'OTHER OBJECT',
#        'OTHER NONCOLLISION', 'REAR TO REAR', 'OVERTURNED', 'ANIMAL',
#        'TRAIN'], dtype=object)

# %%
# collision, fixed, movement, nonmotorist
df_cp4['FIRST_CRASH_TYPE'] = df_cp4['FIRST_CRASH_TYPE'].replace(
    {
        'SIDESWIPE SAME DIRECTION': 'Collision',
        'SIDESWIPE OPPOSITE DIRECTION': 'Collision',
        'REAR END': 'Collision',
        'REAR TO SIDE': 'Collision',
        'HEAD ON': 'Collision',
        'REAR TO FRONT': 'Collision',
        'OTHER OBJECT': 'Collision',
        'REAR TO REAR': 'Collision',

        'PARKED MOTOR VEHICLE': 'Fixed',
        'FIXED OBJECT': 'Fixed',
        'TRAIN': 'Fixed',

        'TURNING': 'Movement',
        'ANGLE': 'Movement',
        'OVERTURNED': 'Movement',

        'PEDALCYCLIST': 'Non-motorist',
        'PEDESTRIAN': 'Non-motorist',
        'ANIMAL': 'Non-motorist',

        'OTHER NONCOLLISION': 'OTHER NONCOLLISION',
    }
)
df_cp4 = df_cp4.rename({'FIRST_CRASH_TYPE': 'CRASH_TYPE'}, axis=1)
df_cp4.loc[:, 'CRASH_TYPE']
# Out:
# 0            Collision
# 1             Movement
# 2                Fixed
# 3         Non-motorist
# 4            Collision
#               ...
# 984007       Collision
# 984008       Collision
# 984009        Movement
# 984010           Fixed
# 984011        Movement
# Name: CRASH_TYPE, Length: 984012, dtype: object

# %%
df_cp4['TRAFFICWAY_TYPE'].unique()
# Out:
# array(['DIVIDED - W/MEDIAN (NOT RAISED)', 'NOT DIVIDED', 'FOUR WAY',
#        'DIVIDED - W/MEDIAN BARRIER', 'ONE-WAY', 'PARKING LOT', 'UNKNOWN',
#        'T-INTERSECTION', 'OTHER', 'TRAFFIC ROUTE', 'DRIVEWAY',
#        'UNKNOWN INTERSECTION TYPE', 'ALLEY', 'Y-INTERSECTION',
#        'FIVE POINT, OR MORE', 'L-INTERSECTION', 'RAMP',
#        'CENTER TURN LANE', 'NOT REPORTED', 'ROUNDABOUT'], dtype=object)

# %%
df_cp4['ROADWAY_SURFACE_COND'].unique()
# Out:
# array(['SNOW OR SLUSH', 'UNKNOWN', 'DRY', 'WET', 'ICE', 'OTHER',
#        'SAND, MUD, DIRT'], dtype=object)

# %%
df_cp4['ROAD_DEFECT'].unique()
# Out:
# array(['NO DEFECTS', 'UNKNOWN', 'SHOULDER DEFECT', 'WORN SURFACE',
#        'RUT, HOLES', 'OTHER', 'DEBRIS ON ROADWAY'], dtype=object)

# %%
df_cp4['ROAD_DEFECT'] = df_cp3['ROAD_DEFECT']

# %%
df_cp4['ROAD_DEFECT'] = df_cp4['ROAD_DEFECT'].replace(
    {
        'NO DEFECTS': False,
        'UNKNOWN': True,
        'SHOULDER DEFECT': True,
        'WORN SURFACE': True,
        'RUT, HOLES': True,
        'OTHER': True,
        'DEBRIS ON ROADWAY': True
    }
)
# Out:
# /var/folders/_9/nyjys43x4nv6dxyk3y75vzh80000gn/T/ipykernel_2961/2626659515.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cp4['ROAD_DEFECT'] = df_cp4['ROAD_DEFECT'].replace(

# %%
df_cp4['PRIM_CONTRIBUTORY_CAUSE'].unique()
# Out:
# array(['IMPROPER TURNING/NO SIGNAL', 'IMPROPER OVERTAKING/PASSING',
#        'UNABLE TO DETERMINE', 'FOLLOWING TOO CLOSELY',
#        'DISREGARDING TRAFFIC SIGNALS', 'IMPROPER LANE USAGE',
#        'FAILING TO YIELD RIGHT-OF-WAY', 'NOT APPLICABLE',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'FAILING TO REDUCE SPEED TO AVOID CRASH',
#        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE', 'WEATHER',
#        'DISREGARDING STOP SIGN', 'IMPROPER BACKING',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'TURNING RIGHT ON RED', 'PHYSICAL CONDITION OF DRIVER',
#        'EQUIPMENT - VEHICLE CONDITION', 'DRIVING ON WRONG SIDE/WRONG WAY',
#        'DISREGARDING ROAD MARKINGS',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'DISTRACTION - FROM OUTSIDE VEHICLE',
#        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)',
#        'TEXTING', 'ROAD CONSTRUCTION/MAINTENANCE',
#        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
#        'DISTRACTION - FROM INSIDE VEHICLE',
#        'CELL PHONE USE OTHER THAN TEXTING', 'ANIMAL',
#        'DISREGARDING OTHER TRAFFIC SIGNS', 'RELATED TO BUS STOP',
#        'OBSTRUCTED CROSSWALKS', 'DISREGARDING YIELD SIGN',
#        'PASSING STOPPED SCHOOL BUS',
#        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'EXCEEDING AUTHORIZED SPEED LIMIT',
#        'EXCEEDING SAFE SPEED FOR CONDITIONS'], dtype=object)

# %%
df_cp4['SEC_CONTRIBUTORY_CAUSE'].unique()
# Out:
# array(['IMPROPER OVERTAKING/PASSING', 'UNABLE TO DETERMINE',
#        'FOLLOWING TOO CLOSELY', 'NOT APPLICABLE',
#        'FAILING TO YIELD RIGHT-OF-WAY',
#        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE', 'WEATHER',
#        'FAILING TO REDUCE SPEED TO AVOID CRASH',
#        'PHYSICAL CONDITION OF DRIVER', 'IMPROPER LANE USAGE',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'IMPROPER BACKING', 'DISREGARDING STOP SIGN',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'IMPROPER TURNING/NO SIGNAL', 'ROAD CONSTRUCTION/MAINTENANCE',
#        'DRIVING ON WRONG SIDE/WRONG WAY', 'DISREGARDING TRAFFIC SIGNALS',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#        'EQUIPMENT - VEHICLE CONDITION',
#        'CELL PHONE USE OTHER THAN TEXTING',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'DISTRACTION - FROM OUTSIDE VEHICLE',
#        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS', 'TEXTING',
#        'TURNING RIGHT ON RED', 'RELATED TO BUS STOP', 'ANIMAL',
#        'DISTRACTION - FROM INSIDE VEHICLE',
#        'DISREGARDING OTHER TRAFFIC SIGNS', 'DISREGARDING YIELD SIGN',
#        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
#        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)',
#        'PASSING STOPPED SCHOOL BUS', 'DISREGARDING ROAD MARKINGS',
#        'OBSTRUCTED CROSSWALKS',
#        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'EXCEEDING SAFE SPEED FOR CONDITIONS',
#        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'EXCEEDING AUTHORIZED SPEED LIMIT'], dtype=object)

# %%
x = pd.Series(df_cp4['PRIM_CONTRIBUTORY_CAUSE'].unique() + df_cp4['SEC_CONTRIBUTORY_CAUSE'].unique())
x.unique()
# Out:
# array(['IMPROPER TURNING/NO SIGNALIMPROPER OVERTAKING/PASSING',
#        'IMPROPER OVERTAKING/PASSINGUNABLE TO DETERMINE',
#        'UNABLE TO DETERMINEFOLLOWING TOO CLOSELY',
#        'FOLLOWING TOO CLOSELYNOT APPLICABLE',
#        'DISREGARDING TRAFFIC SIGNALSFAILING TO YIELD RIGHT-OF-WAY',
#        'IMPROPER LANE USAGEDRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
#        'FAILING TO YIELD RIGHT-OF-WAYWEATHER',
#        'NOT APPLICABLEFAILING TO REDUCE SPEED TO AVOID CRASH',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)PHYSICAL CONDITION OF DRIVER',
#        'FAILING TO REDUCE SPEED TO AVOID CRASHIMPROPER LANE USAGE',
#        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCEOPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'WEATHERIMPROPER BACKING',
#        'DISREGARDING STOP SIGNDISREGARDING STOP SIGN',
#        'IMPROPER BACKINGUNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNERIMPROPER TURNING/NO SIGNAL',
#        'TURNING RIGHT ON REDROAD CONSTRUCTION/MAINTENANCE',
#        'PHYSICAL CONDITION OF DRIVERDRIVING ON WRONG SIDE/WRONG WAY',
#        'EQUIPMENT - VEHICLE CONDITIONDISREGARDING TRAFFIC SIGNALS',
#        'DRIVING ON WRONG SIDE/WRONG WAYEVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#        'DISREGARDING ROAD MARKINGSEQUIPMENT - VEHICLE CONDITION',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORISTCELL PHONE USE OTHER THAN TEXTING',
#        'ROAD ENGINEERING/SURFACE/MARKING DEFECTSVISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)DISTRACTION - FROM OUTSIDE VEHICLE',
#        'DISTRACTION - FROM OUTSIDE VEHICLEROAD ENGINEERING/SURFACE/MARKING DEFECTS',
#        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)TEXTING',
#        'TEXTINGTURNING RIGHT ON RED',
#        'ROAD CONSTRUCTION/MAINTENANCERELATED TO BUS STOP',
#        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)ANIMAL',
#        'DISTRACTION - FROM INSIDE VEHICLEDISTRACTION - FROM INSIDE VEHICLE',
#        'CELL PHONE USE OTHER THAN TEXTINGDISREGARDING OTHER TRAFFIC SIGNS',
#        'ANIMALDISREGARDING YIELD SIGN',
#        'DISREGARDING OTHER TRAFFIC SIGNSHAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
#        'RELATED TO BUS STOPDISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)',
#        'OBSTRUCTED CROSSWALKSPASSING STOPPED SCHOOL BUS',
#        'DISREGARDING YIELD SIGNDISREGARDING ROAD MARKINGS',
#        'PASSING STOPPED SCHOOL BUSOBSTRUCTED CROSSWALKS',
#        'BICYCLE ADVANCING LEGALLY ON RED LIGHTMOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHTEXCEEDING SAFE SPEED FOR CONDITIONS',
#        'EXCEEDING AUTHORIZED SPEED LIMITBICYCLE ADVANCING LEGALLY ON RED LIGHT',
#        'EXCEEDING SAFE SPEED FOR CONDITIONSEXCEEDING AUTHORIZED SPEED LIMIT'],
#       dtype=object)

# %% [markdown]
# ## Renaming a few more columns

# %%
df_cp4 = df_cp4.rename({'ALIGNMENT': 'ROAD_LEVEL', 'DAMAGE': 'DAMAGE_AMT'}, axis=1)

# %% [markdown]
# # Final Cleaned Dataset

# %%
df_clean_data = df_cp4.copy()

# %% [markdown]
# ## Reorder columns

# %%
reordered_columns = [
    'CRASH_DATE',
    'DATE_POLICE_NOTIFIED',

    'ON_SCENE',
    'HIT_AND_RUN',

    'POSTED_SPEED_LIMIT',

    'TRAFFIC_CONTROL_DEVICE',
    'TRAFFIC_DEVICE_FUNCTIONING',

    'WEATHER_CONDITION',
    'LIGHTING_CONDITION',
    'ROADWAY_SURFACE_COND',
    'ROAD_DEFECT',

    'TRAFFICWAY_TYPE',
    'ROAD_LEVEL',

    'DAMAGE_AMT',

    'CRASH_TYPE',

    'PRIM_CONTRIBUTORY_CAUSE',
    'SEC_CONTRIBUTORY_CAUSE',

    'REPORTABLE',
    'INJURIES_TOTAL',
    'INJURIES_FATAL',
    'INJURIES_INCAPACITATING',
    'INJURIES_NON_INCAPACITATING',
    'INJURIES_REPORTED_NOT_EVIDENT',
    'INJURIES_NO_INDICATION',
    'INJURIES_UNKNOWN',

    'LATITUDE',
    'LONGITUDE',
]
df_clean_data = df_clean_data[reordered_columns]

# %%
df_clean_data
# Out:
#                 CRASH_DATE DATE_POLICE_NOTIFIED ON_SCENE HIT_AND_RUN  \
# 0      2025-01-14 12:25:00  2025-01-14 12:38:00        1           1
# 1      2025-05-23 09:30:00  2025-05-27 10:40:00        0           1
# 2      2025-04-05 20:00:00  2025-04-05 21:23:00        1           1
# 3      2025-05-23 09:15:00  2025-05-23 09:16:00        1          -1
# 4      2025-01-14 08:00:00  2025-01-14 08:45:00        0          -1
# ...                    ...                  ...      ...         ...
# 984007 2025-08-07 18:40:00  2025-08-08 15:30:00        0          -1
# 984008 2025-08-16 23:50:00  2025-08-16 23:55:00        1           1
# 984009 2025-08-17 14:00:00  2025-08-18 15:30:00        0          -1
# 984010 2025-08-18 00:08:00  2025-08-18 00:09:00       -1          -1
# 984011 2025-08-18 00:24:00  2025-08-18 00:28:00        1          -1
#
#         POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  TRAFFIC_DEVICE_FUNCTIONING  \
# 0                       30         TRAFFIC SIGNAL                        True
# 1                       30      STOP SIGN/FLASHER                       False
# 2                       30            NO CONTROLS                       False
# 3                       30            NO CONTROLS                       False
# 4                       30         TRAFFIC SIGNAL                        True
# ...                    ...                    ...                         ...
# 984007                  30         TRAFFIC SIGNAL                        True
# 984008                  30            NO CONTROLS                       False
# 984009                  30      STOP SIGN/FLASHER                       False
# 984010                  30            NO CONTROLS                       False
# 984011                  30            NO CONTROLS                       False
#
#        WEATHER_CONDITION      LIGHTING_CONDITION ROADWAY_SURFACE_COND  ...  \
# 0                   SNOW                DAYLIGHT        SNOW OR SLUSH  ...
# 1                UNKNOWN                DAYLIGHT              UNKNOWN  ...
# 2                  CLEAR                 UNKNOWN                  DRY  ...
# 3                  CLEAR                DAYLIGHT                  DRY  ...
# 4                   SNOW                DAYLIGHT                  WET  ...
# ...                  ...                     ...                  ...  ...
# 984007             CLEAR                DAYLIGHT                  DRY  ...
# 984008           UNKNOWN  DARKNESS, LIGHTED ROAD              UNKNOWN  ...
# 984009             CLEAR                DAYLIGHT                  DRY  ...
# 984010             CLEAR  DARKNESS, LIGHTED ROAD                  DRY  ...
# 984011             CLEAR  DARKNESS, LIGHTED ROAD                  DRY  ...
#
#         REPORTABLE INJURIES_TOTAL INJURIES_FATAL  INJURIES_INCAPACITATING  \
# 0            False              0              0                        0
# 1            False              0              0                        0
# 2            False              0              0                        0
# 3             True              1              0                        0
# 4            False              0              0                        0
# ...            ...            ...            ...                      ...
# 984007       False              0              0                        0
# 984008        True              0              0                        0
# 984009       False              0              0                        0
# 984010        True              0              0                        0
# 984011        True              0              0                        0
#
#        INJURIES_NON_INCAPACITATING INJURIES_REPORTED_NOT_EVIDENT  \
# 0                                0                             0
# 1                                0                             0
# 2                                0                             0
# 3                                1                             0
# 4                                0                             0
# ...                            ...                           ...
# 984007                           0                             0
# 984008                           0                             0
# 984009                           0                             0
# 984010                           0                             0
# 984011                           0                             0
#
#        INJURIES_NO_INDICATION INJURIES_UNKNOWN   LATITUDE  LONGITUDE
# 0                           2              0.0  41.997808 -87.655770
# 1                           2              0.0  41.946529 -87.688106
# 2                           1              0.0  41.899325 -87.715074
# 3                           2              0.0  41.902793 -87.699412
# 4                           2              0.0  41.691207 -87.720555
# ...                       ...              ...        ...        ...
# 984007                      2              0.0  42.012120 -87.690100
# 984008                      2              0.0  41.778225 -87.747206
# 984009                      2              0.0  41.838002 -87.641182
# 984010                      1              0.0  41.904205 -87.678698
# 984011                      2              0.0  41.720684 -87.536644
#
# [984012 rows x 27 columns]

# %% [markdown]
# ## Export to CSV

# %%
export_path = lib.path.get_cleaned_path(filename)
df_clean_data.to_csv(export_path)
