# %%
import importlib
import datetime
import json
from pathlib import Path

import pandas as pd
import numpy as np

import lib
importlib.reload(lib)

log = lib.getLogger('yelp_dataset')
working_directory = Path().cwd()
export_directory = working_directory / 'yelp_dataset'
export_clean_directory = export_directory / 'clean'

# %%
path_dataset_review = '/Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/yelp/yelp_dataset/yelp_academic_dataset_review.json'  # 5.34 GB

# %%
df_review = lib.read_json(path_dataset_review)

# %% [markdown]
# ## Cleaning Review Dataset

# %%
df_review
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# ...

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        float64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 480.0+ MB

# %%
lib.info(df_review)
# Out:
# PortfolioLogger.lib.tools: INFO: Null INFO ********************************************
# PortfolioLogger.lib.tools: INFO: 0/9 columns contain null values
# PortfolioLogger.lib.tools: INFO: 0 total null values
# PortfolioLogger.lib.tools: INFO: 0 row(s) contain ALL null values
# PortfolioLogger.lib.tools: INFO: 0 column(s) contain ALL null values
# PortfolioLogger.lib.tools: INFO: Risk Rate INFO ***************************************
# PortfolioLogger.lib.tools: INFO:
#             error_percent error_count
# review_id           0.00%           0
# user_id             0.00%           0
# business_id         0.00%           0
# stars               0.00%           0
# useful              0.00%           0
# funny               0.00%           0
# cool                0.00%           0
# text                0.00%           0
# date                0.00%           0
# PortfolioLogger.lib.tools: INFO: Data Types INFO **************************************
# ...

# %% [markdown]
# Wow, for this there are no null or error values?
# ### Creating backup

# %%
df_review_cp1 = df_review.copy()

# %% [markdown]
# ### Converting 'date' column to Timestamp

# %%
df_review_cp1['date'] = pd.to_datetime(df_review_cp1['date'])

# %%
df_review_cp1
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# ...

# %% [markdown]
# ### Creating a DataFrame just for the review text column (because that take's a lot of memory)

# %%
df_review_cp1
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# ...

# %% [markdown]
# ### Exporting cleaned Review dataset

# %%
lib.export_data(export_clean_directory / 'yelp_review.csv', df_review_cp1)
# Out:
# PortfolioLogger.lib.tools: INFO: Exporting 62912520 elements (5809.09 MB) to /Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/yelp/yelp_dataset/clean/yelp_review_CLEAN.csv
# PortfolioLogger.lib.performance: INFO: <function export_data at 0x10b5b1940> took 57.753 secs to complete.
# PosixPath('/Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/yelp/yelp_dataset/clean/yelp_review_CLEAN.csv')

# %% [markdown]
# # Exploring Review Dataset

# %%
path_df_review = '/Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/yelp/yelp_dataset/clean/yelp_review_CLEAN.csv'  # 5.34 GB

# %%
df = lib.read_data(path_df_review)
# Out:
# PortfolioLogger.lib.tools: INFO: Encoding: ascii
# PortfolioLogger.lib.tools: INFO: Stripping whitespaces from yelp_review_CLEAN.csv
# PortfolioLogger.lib.performance: INFO: <function read_data at 0x14561a0c0> took 2.308 mins to complete.
