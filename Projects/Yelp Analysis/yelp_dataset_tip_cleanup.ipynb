# %%
import importlib
import datetime
import json
from pathlib import Path

import pandas as pd
import numpy as np

import lib
importlib.reload(lib)

log = lib.getLogger('yelp_dataset')
working_directory = Path().cwd()
export_directory = working_directory / 'yelp_dataset'
export_clean_directory = export_directory / 'clean'

# %%
path_dataset_tip = '/Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/yelp/yelp_dataset/yelp_academic_dataset_tip.json'  # 287 MB

# %%
df_tip = lib.read_json(path_dataset_tip)

# %%
df_tip.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                 text                 date  \
# 0                     Avengers time with the ladies.  2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban...  2013-02-05 18:35:10
# 2             It's open even when you think it isn't  2013-08-18 00:56:08
# 3                          Very decent fried chicken  2017-06-27 23:05:38
# 4             Appetizers.. platter special for lunch  2012-10-06 19:43:09
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df_tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908915 entries, 0 to 908914
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           908915 non-null  object
#  1   business_id       908915 non-null  object
#  2   text              908915 non-null  object
#  3   date              908915 non-null  object
#  4   compliment_count  908915 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 34.7+ MB

# %%
lib.info(df_tip)
# Out:
# PortfolioLogger.lib.tools: INFO: Null INFO ********************************************
# PortfolioLogger.lib.tools: INFO: 0/5 columns contain null values
# PortfolioLogger.lib.tools: INFO: 0 total null values
# PortfolioLogger.lib.tools: INFO: 0 row(s) contain ALL null values
# PortfolioLogger.lib.tools: INFO: 0 column(s) contain ALL null values
# PortfolioLogger.lib.tools: INFO: Risk Rate INFO ***************************************
# PortfolioLogger.lib.tools: INFO:
#                  error_percent error_count
# user_id                  0.00%           0
# business_id              0.00%           0
# text                     0.00%           0
# date                     0.00%           0
# compliment_count         0.00%           0
# PortfolioLogger.lib.tools: INFO: Data Types INFO **************************************
# PortfolioLogger.lib.tools: INFO:
#                  has_different_types has_<NA>
# user_id                        False        0
# ...

# %%
df_tip['date'] = pd.to_datetime(df_tip['date'])

# %%
lib.export_data(export_clean_directory / 'yelp_tip.csv', df_tip)
# Out:
# PortfolioLogger.lib.tools: INFO: Exporting 4544575 elements (233.79 MB) to /Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/yelp/yelp_dataset/clean/yelp_tip_CLEAN.csv
# PortfolioLogger.lib.performance: INFO: <function export_data at 0x10b2b58a0> took 1.931 secs to complete.
# PosixPath('/Users/christophermagno/PycharmProjects/MagnoDataAnalystPortfolio/datasets/yelp/yelp_dataset/clean/yelp_tip_CLEAN.csv')
